# %% [markdown]
# # libraries & functions

# %%
import sys
sys.path.append('utility_box/')
from cpath import WSI
import load

# %%
from shapely_utils import make_valid, GeometryCollection, Polygon, mapping, MultiPolygon

# %%
import geojson
from pathlib import Path
from tqdm.auto import tqdm
import xml.etree.ElementTree as ET

# %%
def get_geojson_contour(X, Y):
    contours = []
    for x, y in zip(X, Y):
        contours.append([x, y])
    return contours

def get_geojson_mPolyfeature(polys, groupName='Annotation', color=(246, 122, 73)):
    contours=[]
    for poly in polys:
        x=(np.array(poly.exterior.coords)[:,0]).astype(int).tolist()
        y=(np.array(poly.exterior.coords)[:,1]).astype(int).tolist()
        
        geojson_contour=get_geojson_contour(x,y)
        contours.append([geojson_contour])
        
    properties = {'objectType': 'annotation','name':f"{groupName}" , 'color': color}
    geojson_feature=geojson.Feature(geometry=geojson.MultiPolygon(contours), properties=properties)
    return geojson_feature

# %%
import numpy as np

# %%
def parse_asap_annotations(xml_file):
    # Parse the XML file
    tree = ET.parse(xml_file)
    root = tree.getroot()

    annotations = []

    # Loop through each Annotation element
    for annotation in root.findall(".//Annotation"):
        annotation_name = annotation.get("Name")
        part_of_group = annotation.get("PartOfGroup")
        coordinates = []

        # Find all Coordinate elements inside the Annotation
        for coordinate in annotation.findall(".//Coordinate"):
            x = np.floor(float(coordinate.get("X")))
            y = np.floor(float(coordinate.get("Y")))
            coordinates.append((x, y))

        # Store the annotation's data
        annotations.append({
            "name": annotation_name,
            "group": part_of_group,
            "coordinates": coordinates
        })
    
    return annotations

# %% [markdown]
# # CAMELYON17

# %%
path=Path('PublicDatasets/CAMELYON17')
annotations_folder=Path('PublicDatasets/CAMELYON17/annotations')
slides_folder=Path('PublicDatasets/CAMELYON17/images')

# %%
for idx, annotation_path in enumerate(tqdm(list(annotations_folder.iterdir()))):
    
    annotations=parse_asap_annotations(annotation_path)
    
    updated_path=Path(str(annotation_path.with_suffix('')).replace('annotations','images'))
    slide_path=Path(f"{updated_path}.tif")
    
    geom_dicts=[]
    for annotation in annotations:
        if annotation['group']=='Tumor':
            geom_dicts.append({'geom':Polygon(annotation["coordinates"]).buffer(0), 'group':'Tumor'})
        else:
            geom_dicts.append({'geom':Polygon(annotation["coordinates"]).buffer(0), 'group':'Hole'})

    load.save_pickle(f'{path}/tumor_geoms/{slide_path.stem}.pkl',geom_dicts)
    
    geojson_features=[]
    for geom in geom_dicts:
        geojson_feature = geojson.Feature(geometry=mapping(geom['geom']))
        geojson_feature['properties']["label"]=geom['group']
        geojson_features.append(geojson_feature)
        

    geojson_feature_collection = geojson.FeatureCollection(geojson_features)
    load.save_geojson(f'{path}/tumor_geojson_masks/{slide_path.stem}.geojson', geojson_feature_collection)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_051_node_2.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_089_node_3.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_061_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_009_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_052_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_024_node_2.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_017_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_015_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_045_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_036_node_3.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_010_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_096_node_0.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_067_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_017_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_016_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_024_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_080_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_041_node_0.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_072_node_0.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_086_node_0.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_042_node_3.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_073_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_022_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_017_node_2.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_064_node_0.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_044_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_086_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_075_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_039_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_048_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_099_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_015_node_2.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_068_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_012_node_0.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_046_node_3.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_087_node_0.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_020_node_2.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_020_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_021_node_3.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_034_node_3.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_081_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_092_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_062_node_2.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_088_node_1.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_038_node_2.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_004_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_046_node_4.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_060_node_3.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_040_node_2.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON17/tumor_geojson_masks/patient_066_node_2.geojson' created successfully.

# %% [markdown]
# # CAMELYON16

# %%
path=Path('PublicDatasets/CAMELYON16')
annotations_folder=Path('PublicDatasets/CAMELYON16/annotations')
slides_folder=Path('PublicDatasets/CAMELYON16/images')

# %%
for idx, annotation_path in enumerate(tqdm(list(annotations_folder.iterdir()))):
    
    annotations=parse_asap_annotations(annotation_path)
    
    updated_path=Path(str(annotation_path.with_suffix('')).replace('annotations','images'))
    slide_path=Path(f"{updated_path}.tif")
    
    geom_dicts=[]
    for annotation in annotations:
        if len(annotation["coordinates"])<4:
            continue
            
        if annotation['group']=='Tumor':
            geom_dicts.append({'geom':Polygon(annotation["coordinates"]).buffer(0), 'group':'Tumor'})
        else:
            geom_dicts.append({'geom':Polygon(annotation["coordinates"]).buffer(0), 'group':'Hole'})

    load.save_pickle(f'{path}/tumor_geoms/{slide_path.stem}.pkl',geom_dicts)
    
    geojson_features=[]
    for geom in geom_dicts:
        geojson_feature = geojson.Feature(geometry=mapping(geom['geom']))
        geojson_feature['properties']["label"]=geom['group']
        geojson_features.append(geojson_feature)
        

    geojson_feature_collection = geojson.FeatureCollection(geojson_features)
    load.save_geojson(f'{path}/tumor_geojson_masks/{slide_path.stem}.geojson', geojson_feature_collection)
# Out:
#   0%|          | 0/160 [00:00<?, ?it/s]
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_084.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_091.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_102.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_079.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_108.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_105.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_103.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_001.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_087.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_022.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_018.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_037.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_036.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_046.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_014.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_042.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_011.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_101.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_013.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_114.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_073.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_059.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_026.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_049.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_082.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_072.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_028.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_052.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_110.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_111.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_099.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_013.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_113.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_011.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_085.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_030.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_027.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_070.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_066.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_078.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_038.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_117.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_081.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_009.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_095.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_107.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_058.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_094.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_061.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_077.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_098.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_088.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_016.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_055.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_047.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_021.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_093.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_056.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_073.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_063.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_104.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_074.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_019.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_008.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_097.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_064.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_051.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_010.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_040.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_068.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_099.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_102.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_071.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_041.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_068.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_065.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_027.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_023.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_002.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_086.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_110.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_089.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_067.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_033.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_094.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_007.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_024.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_084.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_029.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_048.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_008.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_080.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_003.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_116.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_106.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_092.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_012.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_104.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_057.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_090.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_053.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_054.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_069.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_062.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_004.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_097.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_065.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_043.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_076.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_066.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_044.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_040.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_122.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_046.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_061.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_004.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_064.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_045.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_082.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_030.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_025.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_006.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_108.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_038.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_029.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_069.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_039.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_035.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_071.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_010.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_002.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_075.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_100.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_092.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_031.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_026.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_051.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_083.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_109.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_017.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_001.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_075.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_032.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_015.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_033.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_016.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_021.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_005.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_105.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_052.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_048.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_050.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_090.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_020.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_074.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_034.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_096.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/test_121.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_079.geojson' created successfully.
# File Saved
# GeoJSON file 'PublicDatasets/CAMELYON16/tumor_geojson_masks/tumor_060.geojson' created successfully.
